# %%
import pandas as pd
import pathlib
import numpy as np

# reading
git_log = pd.read_csv(
    "git.log",
    sep="\t", 
    header=None,
    names=[
        'additions', 
        'deletions', 
        'filename', 
        'sha', 
        'timestamp', 
        'author'])

# converting in "one line"
git_log = git_log[['additions', 'deletions', 'filename']]\
         .join(git_log[['sha', 'timestamp', 'author']]\
         .fillna(method='ffill'))\
         .dropna()

# %%
git_log['timestamp'] = pd.to_datetime(git_log.timestamp, unit='s')
git_log.set_index('timestamp', inplace=True)

git_log['extention'] = git_log.filename.apply(lambda path: pathlib.PurePosixPath(path).suffix) 
git_log.loc[git_log['additions'] == '-', 'additions'] = np.nan 
git_log.loc[git_log['deletions'] == '-', 'deletions'] = np.nan 
git_log['line_count'] = git_log.additions.astype(float) - git_log.deletions.astype(float)

git_log.head(10)
# Out:
#                     additions deletions  \
# timestamp
# 2020-02-03 12:56:01        25        20
# 2020-02-03 09:56:49        22         5
# 2020-02-03 09:39:02         3         1
# 2020-02-03 09:38:43       925         0
# 2020-02-03 09:38:43       NaN       NaN
# 2020-02-03 09:38:43       NaN       NaN
# 2020-02-03 09:38:43       NaN       NaN
# 2020-02-03 09:38:43       NaN       NaN
# 2020-01-27 12:04:13        23        23
# 2020-01-27 09:54:17       357         0
#
#                                                    filename      sha  \
# timestamp
# 2020-02-03 12:56:01                       12_Datenfusion.md  29d83da
# 2020-02-03 09:56:49                       12_Datenfusion.md  0defabd
# 2020-02-03 09:39:02                  11_Regelungstechnik.md  878b126
# 2020-02-03 09:38:43                       12_Datenfusion.md  9675817
# 2020-02-03 09:38:43          img/12_Datenfusion/2DBayes.png  9675817
# 2020-02-03 09:38:43        img/12_Datenfusion/JDLmodell.png  9675817
# 2020-02-03 09:38:43            img/12_Datenfusion/Nahin.png  9675817
# 2020-02-03 09:38:43  img/12_Datenfusion/opencv_matching.jpg  9675817
# 2020-01-27 12:04:13                               README.md  57aae7f
# 2020-01-27 09:54:17                  11_Regelungstechnik.md  95f65b7
#
#                              author extention  line_count
# timestamp
# 2020-02-03 12:56:01  Sebastian Zug        .md         5.0
# 2020-02-03 09:56:49  Sebastian Zug        .md        17.0
# 2020-02-03 09:39:02  Sebastian Zug        .md         2.0
# 2020-02-03 09:38:43  Sebastian Zug        .md       925.0
# 2020-02-03 09:38:43  Sebastian Zug       .png         NaN
# 2020-02-03 09:38:43  Sebastian Zug       .png         NaN
# 2020-02-03 09:38:43  Sebastian Zug       .png         NaN
# 2020-02-03 09:38:43  Sebastian Zug       .jpg         NaN
# 2020-01-27 12:04:13  Sebastian Zug        .md         0.0
# 2020-01-27 09:54:17  Sebastian Zug        .md       357.0

# %%
print("Found {0} commits in project's history".format(git_log.sha.unique().shape[0]))
# Out:
# Found 112 commits in project's history

# %%
md_commits = git_log[git_log.extention == ".md"].sort_index()
md_commits['line_count_cumsum']= md_commits.line_count.cumsum().astype('int')
md_commits['commit_count'] = 1
md_commits['commit_count'] = md_commits['commit_count'].rolling(md_commits.shape[0]).count().astype('int')
md_commits.head()
# Out:
#                     additions deletions  \
# timestamp
# 2019-10-04 04:34:05         2         0
# 2019-10-04 06:11:12       103         2
# 2019-10-04 06:50:29         0         0
# 2019-10-04 06:53:58        59         2
# 2019-10-07 12:00:43        35        11
#
#                                                            filename      sha  \
# timestamp
# 2019-10-04 04:34:05                                       README.md  018d80b
# 2019-10-04 06:11:12                                       README.md  40c4587
# 2019-10-04 06:50:29   00_Einf\303\274hrung.md  => 00_Einfuehrung.md  5e5b3a9
# 2019-10-04 06:53:58                                       README.md  3378e2e
# 2019-10-07 12:00:43                                       README.md  92607e3
#
#                              author extention  line_count  line_count_cumsum  \
# timestamp
# 2019-10-04 04:34:05  Sebastian Zug        .md         2.0                  2
# 2019-10-04 06:11:12  Sebastian Zug        .md       101.0                103
# 2019-10-04 06:50:29  Sebastian Zug        .md         0.0                103
# 2019-10-04 06:53:58  Sebastian Zug        .md        57.0                160
# 2019-10-07 12:00:43  Sebastian Zug        .md        24.0                184
#
#                      commit_count
# timestamp
# 2019-10-04 04:34:05             1
# 2019-10-04 06:11:12             2
# 2019-10-04 06:50:29             3
# 2019-10-04 06:53:58             4
# 2019-10-07 12:00:43             5

# %%
view = md_commits.resample('D').agg({"line_count": "sum", "commit_count": "count"})
view['line_count_cumsum']= view.line_count.cumsum().astype('int')
view
# Out:
#             line_count  commit_count  line_count_cumsum
# timestamp
# 2019-10-04       160.0             4                160
# 2019-10-05         0.0             0                160
# 2019-10-06         0.0             0                160
# 2019-10-07       374.0             6                534
# 2019-10-08        19.0             4                553
# 2019-10-09         0.0             0                553
# 2019-10-10         0.0             0                553
# 2019-10-11        24.0             2                577
# 2019-10-12       139.0             3                716
# 2019-10-13        84.0             2                800
# 2019-10-14        12.0             2                812
# 2019-10-15         0.0             0                812
# 2019-10-16       232.0             4               1044
# 2019-10-17       390.0             4               1434
# 2019-10-18         0.0             0               1434
# 2019-10-19         0.0             0               1434
# 2019-10-20       113.0             2               1547
# 2019-10-21       111.0             4               1658
# 2019-10-22         0.0             0               1658
# 2019-10-23         0.0             0               1658
# 2019-10-24         0.0             0               1658
# 2019-10-25         0.0             0               1658
# 2019-10-26         0.0             0               1658
# 2019-10-27       253.0             3               1911
# 2019-10-28       441.0             2               2352
# 2019-10-29         0.0             0               2352
# 2019-10-30         0.0             0               2352
# 2019-10-31         0.0             0               2352
# 2019-11-01         0.0             0               2352
# 2019-11-02         0.0             0               2352
# ...                ...           ...                ...
# 2020-01-05       374.0             1               6602
# 2020-01-06       174.0             3               6776
# 2020-01-07         0.0             0               6776
# 2020-01-08         0.0             0               6776
# 2020-01-09         0.0             0               6776
# 2020-01-10         0.0             0               6776
# 2020-01-11         0.0             0               6776
# 2020-01-12         0.0             0               6776
# 2020-01-13         0.0             0               6776
# 2020-01-14       212.0             2               6988
# 2020-01-15         0.0             0               6988
# 2020-01-16        94.0             1               7082
# 2020-01-17       239.0             4               7321
# 2020-01-18        19.0             1               7340
# 2020-01-19         0.0             0               7340
# 2020-01-20        82.0             4               7422
# 2020-01-21         0.0             0               7422
# 2020-01-22         0.0             0               7422
# 2020-01-23         0.0             0               7422
# 2020-01-24         0.0             0               7422
# 2020-01-25       183.0             1               7605
# 2020-01-26         0.0             0               7605
# 2020-01-27       376.0             3               7981
# 2020-01-28         0.0             0               7981
# 2020-01-29         0.0             0               7981
# 2020-01-30         0.0             0               7981
# 2020-01-31         0.0             0               7981
# 2020-02-01         0.0             0               7981
# 2020-02-02         0.0             0               7981
# 2020-02-03       949.0             4               8930
#
# [123 rows x 3 columns]
